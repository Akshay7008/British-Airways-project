# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

# %%
#create an empty list to collect all reviews
reviews  = []

#create an empty list to collect rating stars
stars = []

#create an empty list to collect date
date = []

#create an empty list to collect country the reviewer is from
country = []

# %%
for i in range(1, 36):
    page = requests.get(f"https://www.airlinequality.com/airline-reviews/british-airways/page/{i}/?sortby=post_date%3ADesc&pagesize=100")

    soup = BeautifulSoup(page.content, "html5")

    for item in soup.find_all("div", class_="text_content"):
        reviews.append(item.text)

    for item in soup.find_all("div", class_ = "rating-10"):
        try:
            stars.append(item.span.text)
        except:
            print(f"Error on page {i}")
            stars.append("None")

    #date
    for item in soup.find_all("time"):
        date.append(item.text)

    #country
    for item in soup.find_all("h3"):
        country.append(item.span.next_sibling.text.strip(" ()"))
# Out:
# Error on page 33
# Error on page 34
# Error on page 34

# %%
#check the length of total reviews extracted
len(reviews)
# Out:
# 3500

# %%
len(country)
# Out:
# 3500

# %%
#check the length
stars = stars[:3500]

# %%
len(date)
# Out:
# 3500

# %%
# Ensure all lists have the same length by filtering them to the shortest length
min_length = min(len(reviews), len(stars), len(date), len(country))

reviews = reviews[:min_length]
stars = stars[:min_length]
date = date[:min_length]
country = country[:min_length]

# Create the DataFrame
df = pd.DataFrame({"reviews": reviews, "stars": stars, "date": date, "country": country})

# %%
df.head()
# Out:
#                                              reviews  \
# 0  ✅ Trip Verified | Very impressed with BA. Chec...
# 1  ✅ Trip Verified |  LHR - SFO, LAS - LGW August...
# 2  Not Verified |   I flew from Malaga via LHR to...
# 3  ✅ Trip Verified |  Milan to Miami return via L...
# 4  ✅ Trip Verified |  BA created a new low-cost s...
#
#                            stars           date         country
# 0  \n\t\t\t\t\t\t\t\t\t\t\t\t\t5  18th May 2024  United Kingdom
# 1                              9  14th May 2024  United Kingdom
# 2                              3   8th May 2024          Canada
# 3                              2   8th May 2024           Italy
# 4                              1   7th May 2024  United Kingdom

# %%
df.shape
# Out:
# (3418, 4)

# %%
import os

cwd = os.getcwd()
df.to_csv(cwd+ "/BA_reviews.csv")
