# %% [markdown]
# ### **DATA CLEANING**

# %%
#imports

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

#regex
import re

# %%
#create a dataframe from csv file

df=pd.read_csv('BA_reviews.csv',index_col=0)

# %%
df.head()
# Out:
#                                              reviews  stars           date  \
# 0  ✅ Trip Verified | Very impressed with BA. Chec...    5.0  18th May 2024
# 1  ✅ Trip Verified |  LHR - SFO, LAS - LGW August...    9.0  14th May 2024
# 2  Not Verified |   I flew from Malaga via LHR to...    3.0   8th May 2024
# 3  ✅ Trip Verified |  Milan to Miami return via L...    2.0   8th May 2024
# 4  ✅ Trip Verified |  BA created a new low-cost s...    1.0   7th May 2024
#
#           country
# 0  United Kingdom
# 1  United Kingdom
# 2          Canada
# 3           Italy
# 4  United Kingdom

# %% [markdown]
# # **Future Engineering**
#
# Create a new column verified from an exiting column reviews

# %%
df['verified'] = df.reviews.str.contains("Trip Verified")

# %%
df['verified']
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 3413    False
# 3414    False
# 3415    False
# 3416    False
# 3417    False
# Name: verified, Length: 3418, dtype: bool

# %%
df.head()
# Out:
#                                              reviews  stars           date  \
# 0  ✅ Trip Verified | Very impressed with BA. Chec...    5.0  18th May 2024
# 1  ✅ Trip Verified |  LHR - SFO, LAS - LGW August...    9.0  14th May 2024
# 2  Not Verified |   I flew from Malaga via LHR to...    3.0   8th May 2024
# 3  ✅ Trip Verified |  Milan to Miami return via L...    2.0   8th May 2024
# 4  ✅ Trip Verified |  BA created a new low-cost s...    1.0   7th May 2024
#
#           country  verified
# 0  United Kingdom      True
# 1  United Kingdom      True
# 2          Canada     False
# 3           Italy      True
# 4  United Kingdom      True

# %%
#for lemmatization of words we will use nltk library
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
lemma = WordNetLemmatizer()

# %%
reviews_data = df.reviews.str.strip("✅ Trip Verified |")

# %%
reviews_data
# Out:
# 0       y impressed with BA. Check in online was a lit...
# 1       LHR - SFO, LAS - LGW August 2023 in Club World...
# 2       Not Verified |   I flew from Malaga via LHR to...
# 3       Milan to Miami return via London. Worst busine...
# 4       BA created a new low-cost subsidiary in BA Eur...
#                               ...
# 3413    BRU-Toronto-BRU 1st class. In BRU check in pas...
# 3414    BA2706 and BA2707 LGW-BCN. No real issues plea...
# 3415    BA 0027 ex London HR to Hong Kong which depart...
# 3416    We travelled economy from Manchester to Toront...
# 3417    Flight LGW to TFS in Business. Like another re...
# Name: reviews, Length: 3418, dtype: object

# %%
import nltk
nltk.download('wordnet')
# !python3 -m nltk.downloader stopwords
corpus =[]

#loop through each review, remove punctuations, small case it, join it and add it to corpus
for rev in reviews_data:
    rev = re.sub('[^a-zA-Z]',' ', rev)
    rev = rev.lower()
    rev = rev.split()
    rev = [lemma.lemmatize(word) for word in rev if word not in set(stopwords.words("english"))]
    rev = " ".join(rev)
    corpus.append(rev)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# /usr/lib/python3.10/runpy.py:126: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df['corpus'] = corpus

# %%
df.head()
# Out:
#                                              reviews  stars           date  \
# 0  ✅ Trip Verified | Very impressed with BA. Chec...    5.0  18th May 2024
# 1  ✅ Trip Verified |  LHR - SFO, LAS - LGW August...    9.0  14th May 2024
# 2  Not Verified |   I flew from Malaga via LHR to...    3.0   8th May 2024
# 3  ✅ Trip Verified |  Milan to Miami return via L...    2.0   8th May 2024
# 4  ✅ Trip Verified |  BA created a new low-cost s...    1.0   7th May 2024
#
#           country  verified                                             corpus
# 0  United Kingdom      True  impressed ba check online little convoluted ev...
# 1  United Kingdom      True  lhr sfo la lgw august club world shame british...
# 2          Canada     False  verified flew malaga via lhr boston th may arr...
# 3           Italy      True  milan miami return via london worst business c...
# 4  United Kingdom      True  ba created new low cost subsidiary ba euroflye...

# %%
df.dtypes
# Out:
# reviews      object
# stars       float64
# date         object
# country      object
# verified       bool
# corpus       object
# dtype: object

# %%
df.stars.unique()
# Out:
# array([ 5.,  9.,  3.,  2.,  1.,  4.,  6., 10.,  7.,  8., nan])

# %%
df.stars.value_counts()
# Out:
# stars
# 1.0     837
# 3.0     394
# 2.0     394
# 8.0     331
# 10.0    282
# 7.0     273
# 9.0     262
# 5.0     241
# 4.0     232
# 6.0     169
# Name: count, dtype: int64

# %%
df.isnull().value_counts()
# Out:
# reviews  stars  date   country  verified  corpus
# False    False  False  False    False     False     3414
#          True   False  False    False     False        3
#          False  False  True     False     False        1
# Name: count, dtype: int64

# %%
df.country.isnull().value_counts()
# Out:
# country
# False    3417
# True        1
# Name: count, dtype: int64

# %%
#drop the rows using index where the country value is null
df.drop(df[df.country.isnull() == True].index, axis=0, inplace=True)

# %%
df.shape
# Out:
# (3417, 6)

# %%
df.reset_index(drop=True)
# Out:
#                                                 reviews  stars  \
# 0     ✅ Trip Verified | Very impressed with BA. Chec...    5.0
# 1     ✅ Trip Verified |  LHR - SFO, LAS - LGW August...    9.0
# 2     Not Verified |   I flew from Malaga via LHR to...    3.0
# 3     ✅ Trip Verified |  Milan to Miami return via L...    2.0
# 4     ✅ Trip Verified |  BA created a new low-cost s...    1.0
# ...                                                 ...    ...
# 3412  BRU-Toronto-BRU 1st class. In BRU check in pas...    9.0
# 3413  BA2706 and BA2707 LGW-BCN. No real issues plea...    8.0
# 3414  BA 0027 ex London HR to Hong Kong which depart...   10.0
# 3415  We travelled economy from Manchester to Toront...    4.0
# 3416  Flight LGW to TFS in Business. Like another re...    6.0
#
#                    date         country  verified  \
# 0         18th May 2024  United Kingdom      True
# 1         14th May 2024  United Kingdom      True
# 2          8th May 2024          Canada     False
# 3          8th May 2024           Italy      True
# 4          7th May 2024  United Kingdom      True
# ...                 ...             ...       ...
# 3412  5th November 2014         Belgium     False
# 3413  3rd November 2014  United Kingdom     False
# 3414  3rd November 2014       Australia     False
# 3415  3rd November 2014  United Kingdom     False
# 3416  3rd November 2014  United Kingdom     False
#
#                                                  corpus
# 0     impressed ba check online little convoluted ev...
# 1     lhr sfo la lgw august club world shame british...
# 2     verified flew malaga via lhr boston th may arr...
# 3     milan miami return via london worst business c...
# 4     ba created new low cost subsidiary ba euroflye...
# ...                                                 ...
# 3412  bru toronto bru st class bru check passport co...
# 3413  ba ba lgw bcn real issue pleasant crew flight ...
# 3414  ba ex london hr hong kong departed hong kong l...
# 3415  travelled economy manchester toronto via heath...
# 3416  flight lgw tfs business like another reviewer ...
#
# [3417 rows x 6 columns]

# %%
# export the cleaned data

df.to_csv(cwd + "/cleaned-BA-reviews.csv")
